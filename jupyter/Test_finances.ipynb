# %%
import numpy as np
def square(x):
    return x * x

# %%
x = np.random.randint(1, 10)
y = square(x)
print('%d squared is %d' % (x, y))
# Out:
# 2 squared is 4

# %%
# Import the yfinance. If you get module not found error the run !pip install yfianance from your Jupyter notebook
import yfinance as yf

# Get the data for the stock AAPL
data = yf.download('CL=F','2017-01-01','2020-03-18')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
data['Adj Close'].plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf

# Get the data for the stock AAPL
data = yf.download('CL=F','2013-01-01','2020-03-18')['Adj Close']
data1 = yf.download('USDRUB=X','2013-01-01','2020-03-18')['Adj Close'].copy()

data1.loc['2016-01-06'] *= 100 #wrong rate that day

data = data * data1

data.dropna().plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Out:
# Date
# 2020-03-12    2411.332596
# 2020-03-13    2466.394515
# 2020-03-15            NaN
# 2020-03-16    2323.841674
# 2020-03-17    1965.980621
# Name: Adj Close, dtype: float64

# %%
import yfinance as yf
data = yf.download('CL=F','2013-01-01','2020-03-18')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.dropna().plot()

# %%
data2 = data.dropna()[(data.T != 0)]
data3 = data2[data.T < 1000]
data1['2016-01-06']
# Out:
# 71.61999940872192

# %%
import yfinance as yf

# Get the data for the stock AAPL
data = yf.download('USDRUB=X','2013-01-01','2020-03-18')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data1 = data.copy()
data1.loc['2016-01-06']/=100
data1.plot()
